# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuska12q34/python-codes-collab/blob/main/Dictionary_and_sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
info ={
    "name":"anuska",
    "age":20,
    "subjects": ["PYTHON","C++","JAVA"],
    "marks":{
        "PYTHON":89,
        "C++":82,
        "JAVA":93
    }
}
print(info["name"])
print(info["age"])
print(info["subjects"])
print(info["marks"])
# Out:
# anuska
# 20
# ['PYTHON', 'C++', 'JAVA']
# {'PYTHON': 89, 'C++': 82, 'JAVA': 93}
