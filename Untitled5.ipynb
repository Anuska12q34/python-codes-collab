# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuska12q34/python-codes-collab/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Relational operators
a = 50
b = 20

print("a==b:", a==b)
print("a!=b:", a!=b)
print("a>=b:", a>=b)
print("a>b:", a>b)
print("a<=b:", a<=b)
print("a<b:", a<b)
# Out:
# a==b: False
# a!=b: True
# a>=b: True
# a>b: True
# a<=b: False
# a<b: False
