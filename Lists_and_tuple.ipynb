# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuska12q34/python-codes-collab/blob/main/Lists_and_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Movies =input("ENTER 3 OF YOUR FAVE MOVIES:").split()
print("YOUR FAVE MOVIES ARE: ", Movies)
# Out:
# ENTER 3 OF YOUR FAVE MOVIES:YJHD ZNMD K3G
# YOUR FAVE MOVIES ARE:  ['YJHD', 'ZNMD', 'K3G']
