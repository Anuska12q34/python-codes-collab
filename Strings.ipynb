# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuska12q34/python-codes-collab/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str = "Hello!!Welcome!!"
print(str[0:7])
#or print(str[:4])
print(str[7:])
# or print(str[7:len(str)]);
# or print(str[7:16])
# Out:
# Hello!!
# Welcome!!

# %%
#NEGATIVE INDEXING
str= "HOW ARE YOU DOING?"
print(str[-19:-6])
print(str[-14:])
# Out:
# HOW ARE YOU
# ARE YOU DOING?

# %%
str="i am studying pythong for the first time."
print(str.endswith("."))
str = str.capitalize()
print(str)
print(str.replace("first","second"))
print(str.find("for"))
print(str.count("i"))
print
# Out:
# True
# I am studying pythong for the first time.
# I am studying pythong for the second time.
# 22
# 3
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
